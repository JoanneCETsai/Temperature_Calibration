# %%
# %run "data_processing_.ipynb"
# %run "load_data_.ipynb"
# %run "get_backbround_average_.ipynb"

# %%
aa, bb, cc, ee, dd = get_needed_files('/Users/chiaentsai/Box/MURI-SARA/Thermoreflectance/Joanne/11092022_4')
back = get_background_average(bb)

# %%
whole = get_blue("/Users/chiaentsai/Box/MURI-SARA/Thermoreflectance/Joanne/11092022_4/9mm_per_sec/2mm_35W_023.raw")
zoomin = get_bright(whole)
b_whole = back[7]
b_zoomin = get_bright(b_whole)
needed = zoomin - b_zoomin
plt.imshow(whole - b_whole)

# %%
plt.imshow(needed)

# %%
plt.plot(needed[50,:])
