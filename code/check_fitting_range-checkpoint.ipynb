# %%
# %run "data_processing_.ipynb"
# %run "load_data_.ipynb"
# %run "get_backbround_average_.ipynb"
# %run "curve_fit_.ipynb"
# %run "fitting_functions_.ipynb"

# %%
aa, bb, cc, ee, dd = get_needed_files('/Users/chiaentsai/Library/CloudStorage/Box-Box/MURI-SARA/Thermoreflectance/Joanne/CHESS/0130_2023')
back = get_background_average(bb)
# Out:
# []

# %%
aa
# Out:
# {}

# %%
whole = get_blue("/Users/chiaentsai/Library/CloudStorage/Box-Box/MURI-SARA/Thermoreflectance/Joanne/CHESS/0130_2023/30mm_per_sec/-12mm_35W_012.raw")
zoomin = get_bright(whole)
b_whole = back[0]
b_zoomin = get_bright(b_whole)
needed = zoomin - b_zoomin
# fig 1: background
sc = plt.imshow(b_whole)
plt.colorbar(sc)
plt.title("background")
plt.show()
# fig 2: intensity without background
sc = plt.imshow(whole-b_whole)
plt.colorbar(sc)
plt.title("intensity without background")
plt.show()
# fig 3: vertical direction trend
plt.plot((whole-b_whole)[:,325])
plt.title("vertical direction")
plt.xlabel("pixel")
plt.ylabel("intensity")
plt.show()
# fig 4: horizontal direction trend
plt.plot((whole-b_whole)[200,:])
plt.title("horizontal direction")
plt.xlabel("pixel")
plt.ylabel("intensity")
plt.show()
# fig 5: dR/R intensity
sc = plt.imshow((whole - b_whole)/b_whole)
plt.colorbar(sc)
plt.title("dR/R")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /Users/chiaentsai/Desktop/lab/Temperature_Calibration/code/check_fitting_range-checkpoint.ipynb Cell 4 in <module>
#       <a href='vscode-notebook-cell:/Users/chiaentsai/Desktop/lab/Temperature_Calibration/code/check_fitting_range-checkpoint.ipynb#W3sZmlsZQ%3D%3D?line=0'>1</a> whole = get_blue("/Users/chiaentsai/Library/CloudStorage/Box-Box/MURI-SARA/Thermoreflectance/Joanne/CHESS/0130_2023/30mm_per_sec/-12mm_35W_012.raw")
#       <a href='vscode-notebook-cell:/Users/chiaentsai/Desktop/lab/Temperature_Calibration/code/check_fitting_range-checkpoint.ipynb#W3sZmlsZQ%3D%3D?line=1'>2</a> zoomin = get_bright(whole)
# ----> <a href='vscode-notebook-cell:/Users/chiaentsai/Desktop/lab/Temperature_Calibration/code/check_fitting_range-checkpoint.ipynb#W3sZmlsZQ%3D%3D?line=2'>3</a> b_whole = back[0]
#       <a href='vscode-notebook-cell:/Users/chiaentsai/Desktop/lab/Temperature_Calibration/code/check_fitting_range-checkpoint.ipynb#W3sZmlsZQ%3D%3D?line=3'>4</a> b_zoomin = get_bright(b_whole)
#       <a href='vscode-notebook-cell:/Users/chiaentsai/Desktop/lab/Temperature_Calibration/code/check_fitting_range-checkpoint.ipynb#W3sZmlsZQ%3D%3D?line=4'>5</a> needed = zoomin - b_zoomin
#
# IndexError: list index out of range

# %%
plt.imshow(needed)

# %%
# a,b,c,d = fit(two_lorentz, needed[20,:])
# plt.plot(needed[20,:])
# plt.plot(np.linspace(0,59,60), two_lorentz(np.linspace(0,59,60),a,b,c,d))

a,b,c,d = fit(two_lorentz, needed[:,25])
plt.plot(needed[:,25])
plt.plot(np.linspace(0,149,150), two_lorentz(np.linspace(0,149,150),a,b,c,d))
