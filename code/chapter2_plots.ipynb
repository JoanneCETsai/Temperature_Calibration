# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

# Define the range of x and y
x = np.linspace(0, 10, 100)  # Example x range
y = np.arange(0, 11, 0.5)  # Example y positions with 0.5 intervals

# Create a meshgrid for x and y
X, Y = np.meshgrid(x, y)

# Compute the Gaussian values for each x and y combination
max_gaussian = np.exp(-0.5 * ((y - 5) / 2)**2)  # Gaussian distribution for maximum values
gaussian = max_gaussian[:, np.newaxis] * np.exp(-0.5 * ((X - 5) / 2)**2)  # Gaussian lines with maximum values

# Find the indices of the maximum points along the x-axis
max_indices = np.argmax(gaussian, axis=1)

# Create the 3D plot
fig = plt.figure(figsize=(10, 8))
ax = fig.add_subplot(111, projection='3d')

# Set a single color for all the lines and points
line_color = 'orange'
point_color = 'red'

# Plot the Gaussian lines
for yi in range(len(y)):
    ax.plot(x, y[yi] * np.ones_like(x), gaussian[yi], color=line_color, label=f"y = {y[yi]:.1f}")

# Plot red points at the maximum points
for yi, max_index in enumerate(max_indices):
    ax.scatter(x[max_index], y[yi], gaussian[yi, max_index], color=point_color)

# Remove the ticks
ax.set_xticks([])
ax.set_yticks([])
ax.set_zticks([])

# Customize the plot
ax.set_xlabel('X', fontsize=18)
ax.set_ylabel('Y', fontsize=18)
ax.set_zlabel('Z')

# Add z-axis label manually
ax.text2D(0.4, 0.95, 'dR/R Value', transform=ax.transAxes, fontsize=18)

# Set plot title
#ax.set_title('3D Plot with Gaussian Lines')

# Show the legend
# ax.legend()

# Show the plot
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

# Define the range of x and y
x = np.linspace(0, 10, 100)  # Example x range
y = np.arange(0, 11, 0.5)  # Example y positions with 0.5 intervals

# Create a meshgrid for x and y
X, Y = np.meshgrid(x, y)

# Compute the Gaussian values for each x and y combination
max_gaussian = np.exp(-0.5 * ((y - 5) / 2)**2)  # Gaussian distribution for maximum values
gaussian = max_gaussian[:, np.newaxis] * np.exp(-0.5 * ((X - 5) / 2)**2)  # Gaussian lines with maximum values

# Find the indices of the maximum points along the x-axis
max_indices = np.argmax(gaussian, axis=1)

# Create the 3D plot
fig = plt.figure(figsize=(10, 8))
ax = fig.add_subplot(111, projection='3d')

# Set a single color for all the lines and points
line_color = 'orange'
point_color = 'red'

# Plot the Gaussian lines
for yi in range(len(y)):
    ax.plot(x, y[yi] * np.ones_like(x), gaussian[yi], color=line_color, label=f"y = {y[yi]:.1f}")

# Plot red points at the maximum points
for yi, max_index in enumerate(max_indices):
    ax.scatter(x[max_index], y[yi], gaussian[yi, max_index], color=point_color)

# Connect the red points with a red line
red_points = np.column_stack((x[max_indices], y, gaussian[np.arange(len(y)), max_indices]))
ax.plot(red_points[:, 0], red_points[:, 1], red_points[:, 2], color=point_color, label='Red Line')

# Remove the ticks
ax.set_xticks([])
ax.set_yticks([])
ax.set_zticks([])

# Customize the plot
ax.set_xlabel('X', fontsize=18)
ax.set_ylabel('Y', fontsize=18)
ax.set_zlabel('Z')

# Add z-axis label manually
ax.text2D(0.4, 0.95, 'dR/R Value', transform=ax.transAxes, fontsize=18)
# Set plot title
ax.set_title('3D Plot with Gaussian Lines')

# Show the legend
#ax.legend()

# Show the plot
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

# Define the range of x and y
x = np.linspace(0, 10, 100)  # Example x range
y = np.arange(0, 11, 0.5)  # Example y positions with 0.5 intervals

# Create a meshgrid for x and y
X, Y = np.meshgrid(x, y)

# Compute the Gaussian values for each x and y combination
max_gaussian = np.exp(-0.5 * ((y - 5) / 2)**2)  # Gaussian distribution for maximum values
gaussian = max_gaussian[:, np.newaxis] * np.exp(-0.5 * ((X - 5) / 2)**2)  # Gaussian lines with maximum values

# Find the indices of the maximum points along the x-axis
max_indices = np.argmax(gaussian, axis=1)

# Create the 3D plot
fig = plt.figure(figsize=(10, 8))
ax = fig.add_subplot(111, projection='3d')

# Set a single color for all the lines and points
line_color = 'red'
point_color = 'purple'

# Connect the red points with a red line
red_points = np.column_stack((x[max_indices], y, gaussian[np.arange(len(y)), max_indices]))
ax.plot(red_points[:, 0], red_points[:, 1], red_points[:, 2], color=line_color, label='Red Line')

# Plot a purple point at the maximum point of the red line
max_point = red_points[np.argmax(red_points[:, 2])]
ax.scatter(max_point[0], max_point[1], max_point[2], color=point_color, s=100, label='Purple Point')

# Remove the ticks
ax.set_xticks([])
ax.set_yticks([])
ax.set_zticks([])

# Customize the plot
ax.set_xlabel('X', fontsize=18)
ax.set_ylabel('Y', fontsize=18)
ax.set_zlabel('Z')

# Add z-axis label manually
ax.text2D(0.4, 0.95, 'dR/R Value', transform=ax.transAxes, fontsize=18)

# Set plot title
ax.set_title('3D Plot with Red Line and Purple Point')

# Show the legend
ax.legend()

# Show the plot
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

# Define the range of x and y
x = np.linspace(0, 10, 100)  # Example x range
y = np.arange(0, 11, 0.5)  # Example y positions with 0.5 intervals

# Create a meshgrid for x and y
X, Y = np.meshgrid(x, y)

# Compute the Gaussian values for each x and y combination
max_gaussian = np.exp(-0.5 * ((y - 5) / 2)**2)  # Gaussian distribution for maximum values
gaussian = max_gaussian[:, np.newaxis] * np.exp(-0.5 * ((X - 5) / 2)**2)  # Gaussian lines with maximum values

# Find the indices of the maximum points along the x-axis
max_indices = np.argmax(gaussian, axis=1)

# Create the 3D plot
fig = plt.figure(figsize=(10, 8))
ax = fig.add_subplot(111, projection='3d')

# Set colors for the lines and points
line_color = 'orange'
red_line_color = 'red'
point_color = 'purple'

# Plot the Gaussian lines (orange)
for yi in range(len(y)):
    ax.plot(x, y[yi] * np.ones_like(x), gaussian[yi], color=line_color, label=f"y = {y[yi]:.1f}")

# Connect the red points with a red line
red_points = np.column_stack((x[max_indices], y, gaussian[np.arange(len(y)), max_indices]))
ax.plot(red_points[:, 0], red_points[:, 1], red_points[:, 2], color=red_line_color, label='Red Line')

# Plot a purple point at the maximum point of the red line
max_point = red_points[np.argmax(red_points[:, 2])]
ax.scatter(max_point[0], max_point[1], max_point[2], color=point_color, s=100, label='Purple Point')

# Remove the ticks
ax.set_xticks([])
ax.set_yticks([])
ax.set_zticks([])

# Customize the plot
ax.set_xlabel('X', fontsize=18)
ax.set_ylabel('Y', fontsize=18)
ax.set_zlabel('Z')

# Add z-axis label manually
ax.text2D(0.4, 0.95, 'dR/R Value', transform=ax.transAxes, fontsize=18)

# Set plot title
#ax.set_title('3D Plot with Gaussian Lines, Red Line, and Purple Point')

# Show the legend
#ax.legend()

# Show the plot
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

# Define the range of x and y
x = np.arange(0, 11, 0.5)  # Example x positions with 0.5 intervals (0 to 10)
y = np.linspace(0, 10, 100)  # Example y range

# Create a meshgrid for x and y
X, Y = np.meshgrid(x, y)

# Compute the Gaussian values for each x and y combination
max_gaussian = np.exp(-0.5 * ((y - 5) / 2)**2)  # Gaussian distribution for maximum values
gaussian = max_gaussian[:, np.newaxis] * np.exp(-0.5 * ((Y - 5) / 2)**2)  # Gaussian lines with maximum values

# Find the indices of the maximum points along the y-axis
max_indices = np.argmax(gaussian, axis=0)

# Create the 3D plot
fig = plt.figure(figsize=(10, 8))
ax = fig.add_subplot(111, projection='3d')

# Set a single color for all the lines and points
line_color = 'orange'
point_color = 'red'

# Plot the Gaussian lines
for xi in range(len(x)):
    ax.plot(x[xi] * np.ones_like(y), y, gaussian[:, xi], color=line_color, label=f"x = {x[xi]:.1f}")

# Plot red points at the maximum points
for xi, max_index in enumerate(max_indices):
    ax.scatter(x[xi], y[max_index], gaussian[max_index, xi], color=point_color)

# Remove the ticks
ax.set_xticks([])
ax.set_yticks([])
ax.set_zticks([])

# Customize the plot
ax.set_xlabel('X', fontsize=18)
ax.set_ylabel('Y', fontsize=18)
ax.set_zlabel('Z')

# Add z-axis label manually
ax.text2D(0.4, 0.95, 'dR/R Value', transform=ax.transAxes, fontsize=18)

# Set plot title
# ax.set_title('3D Plot with Gaussian Lines')

# Show the legend
# ax.legend()

# Show the plot
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

# Generate the x and y values
x = np.arange(0, 51)  # x = 0 to 50
y = np.linspace(0, 10, 100)  # y = 0 to 10 with 100 points

# Calculate the Gaussian values for each x
mean = 5
std_dev = 2
Z = np.exp(-(y - mean) ** 2 / (2 * std_dev ** 2))

# Create 2D meshgrids for the x and y values
X, Y = np.meshgrid(x, y)

# Repeat the Gaussian values along the x-axis
Z = np.tile(Z, (len(x), 1))

# Plot the 3D surface with orange color
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.plot_surface(X, Y, Z.T, color='pink')  # Transpose Z to match the shape of X and Y

# Set labels and title
ax.set_xlabel('X')
ax.set_ylabel('Y')
ax.set_zlabel('Z')
ax.set_title('3D Gaussian Plot')

# Show the plot
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

# Define the range of x and y
x = np.linspace(0, 10, 100)  # Example x range
y = np.arange(0, 11, 0.5)  # Example y positions with 0.5 intervals

# Create a meshgrid for x and y
X, Y = np.meshgrid(x, y)

# Compute the Gaussian values for each x and y combination
max_gaussian = np.exp(-0.5 * ((y - 5) / 2)**2)  # Gaussian distribution for maximum values
gaussian = max_gaussian[:, np.newaxis] * np.exp(-0.5 * ((X - 5) / 2)**2)  # Gaussian lines with maximum values

# Create the 3D plot
fig = plt.figure(figsize=(10, 8))
ax = fig.add_subplot(111, projection='3d')

# Plot the Gaussian surface
ax.plot_surface(X, Y, gaussian, cmap='viridis')

# Customize the plot
ax.set_xlabel('X', fontsize=18)
ax.set_ylabel('Y', fontsize=18)
ax.set_zlabel('Z')
ax.set_xticks([])
ax.set_yticks([])
ax.set_zticks([])
ax.set_title('dR/R Value')

# Show the plot
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

# Define the range of x and y
x = np.linspace(0, 10, 100)  # Example x range
y = np.arange(0, 11, 0.5)  # Example y positions with 0.5 intervals

# Create a meshgrid for x and y
X, Y = np.meshgrid(x, y)

# Compute the Gaussian values for each x and y combination
max_gaussian = np.exp(-0.5 * ((y - 5) / 2)**2)  # Gaussian distribution for maximum values
gaussian = max_gaussian[:, np.newaxis] * np.exp(-0.5 * ((X - 5) / 2)**2)  # Gaussian lines with maximum values

# Find the indices of the maximum points along the x-axis
max_indices = np.argmax(gaussian, axis=1)

# Create the 3D plot
fig = plt.figure(figsize=(10, 8))
ax = fig.add_subplot(111, projection='3d')

# Set a single color for all the lines and points
line_color = 'orange'
point_color = 'blue'

# Plot the Gaussian lines
for yi in range(len(y)):
    ax.plot(y[yi] * np.ones_like(x),x, gaussian[yi], color=line_color, label=f"y = {y[yi]:.1f}")

# Plot red points at the maximum points
for yi, max_index in enumerate(max_indices):
    ax.scatter(y[yi], x[max_index], 0, color=point_color)

# Remove the ticks
ax.set_xticks([])
ax.set_yticks([])
ax.set_zticks([])

# Customize the plot
ax.set_xlabel('X', fontsize=18)
ax.set_ylabel('Y', fontsize=18)
ax.set_zlabel('Z')

# Add z-axis label manually
ax.text2D(0.4, 0.95, 'dR/R Value', transform=ax.transAxes, fontsize=18)


plt.show()
