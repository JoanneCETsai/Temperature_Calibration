# %%
# %run "data_processing_.ipynb"
# %run "load_data_.ipynb"
# %run "get_backbround_average_.ipynb"
# %run "curve_fit_.ipynb"
# %run "fitting_functions_.ipynb"

# %%
aa, bb, cc, ee, dd = get_needed_files('/Users/chiaentsai/Box/MURI-SARA/Thermoreflectance/Joanne/CHESS/0128_2023_shutter_delay')
back = get_background_average(bb)

# %%
whole = get_blue("/Users/chiaentsai/Box/MURI-SARA/Thermoreflectance/Joanne/CHESS/0128_2023_shutter_delay/9mm_per_sec/10mm_34W_019.raw")
zoomin = get_bright(whole)
b_whole = back[0]
b_zoomin = get_bright(b_whole)
needed = zoomin - b_zoomin
plt.imshow(whole - b_whole)

# %%
plt.imshow(needed)

# %%
needed[50,:]
a,b,c,d = fit(two_lorentz, needed[50,:])
plt.plot(needed[50,:])
plt.plot(np.linspace(0,149,250), two_lorentz(np.linspace(0,149,250),a,b,c,d))

# %%
# this is for test
