# %%
# %run "data_processing_.ipynb"
# %run "load_data_.ipynb"
# %run "get_backbround_average_.ipynb"
# %run "curve_fit_.ipynb"
# %run "fitting_functions_.ipynb"

# %%
aa, bb, cc, ee, dd = get_needed_files('/Users/chiaentsai/Box/MURI-SARA/Thermoreflectance/Joanne/CHESS/0130_2023')
back = get_background_average(bb)
# Out:
# [4, 28, 2, 2, 18, 2, 12, 1, 8, 5, 41]

# %%
whole = get_blue("/Users/chiaentsai/Box/MURI-SARA/Thermoreflectance/Joanne/CHESS/0130_2023/103mm_per_sec/-18mm_39W_004.raw")
zoomin = get_bright(whole)
b_whole = back[0]
b_zoomin = get_bright(b_whole)
needed = zoomin - b_zoomin
sc = plt.imshow(b_whole)
plt.colorbar(sc)
plt.show()
sc = plt.imshow(whole-b_whole)
plt.colorbar(sc)
plt.show()
plt.plot((whole-b_whole)[:,400])
plt.show()
plt.plot((whole-b_whole)[210,:])
plt.show()
sc = plt.imshow((whole - b_whole)/b_whole)
plt.colorbar(sc)
plt.show()

# %%
plt.imshow(needed)

# %%
a,b,c,d = fit(two_lorentz, needed[:,75])
plt.plot(needed[:,75])
plt.plot(np.linspace(0,59,60), two_lorentz(np.linspace(0,59,60),a,b,c,d))
